# %%
import sys
import os
import pandas as pd
from datetime import datetime

project_root = os.path.abspath(os.path.join(".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.extract_news import ExtractNews
from src.extract_yahoo import ExtractYahoo
from src.pipeline import Pipeline
from src.logger_config import setup_logger
from src.transform import Transform
from src.init_db import init_db
from src.load import Load

RAW_DIR = "../data/raw"
PROCESSED_DIR = "../data/processed"
LOG_DIR = "../logs/pipeline"
DB_PATH = "../data/analytcs/pipeline.db"
SCHEMA_FILE = "../data/database/create_tables.sql"

os.makedirs(RAW_DIR, exist_ok=True)
os.makedirs(PROCESSED_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

logger, log_file = setup_logger("PipelineLogger", log_dir=LOG_DIR)
logger.info("Início da execução da pipeline")

init_db(db_path=DB_PATH, schema_file=SCHEMA_FILE)
# Out:
# 15-10-25 21:32:47 [INFO] Início da execução da pipeline
# ✅ Banco inicializado em: ../data/database/pipeline.db

# %%
urls = {
    "g1": [
        "https://g1.globo.com/ce/ceara/",
        "https://g1.globo.com/",
        "https://g1.globo.com/economia/",
        "https://g1.globo.com/politica/",
        "https://g1.globo.com/mundo/",
        "https://g1.globo.com/ciencia-e-saude/",
        "https://g1.globo.com/tecnologia/",
    ],
    "folha": ["https://www1.folha.uol.com.br/ultimas-noticias/"],
}

task_news = ExtractNews(urls)
task_yahoo = ExtractYahoo("https://finance.yahoo.com/quote/DSPY/", tickers=None)

# %%
pipeline = Pipeline([task_news, task_yahoo])
resultado = pipeline.run()
logger.info("Extração finalizada com sucesso!")

# %%
timestamp = datetime.now().strftime("%d-%m-%y_%H-%M-%S")

df_news = resultado.get("ExtractNews", pd.DataFrame())
df_yahoo = resultado.get("ExtractYahoo", pd.DataFrame())

if not df_news.empty:
    csv_news = os.path.join(RAW_DIR, f"ExtractNews_{timestamp}.csv")
    df_news.to_csv(csv_news, index=False, encoding="utf-8")
    logger.info(f"CSV de ExtractNews cru salvo em: {csv_news}")

if not df_yahoo.empty:
    csv_yahoo = os.path.join(RAW_DIR, f"ExtractYahoo_{timestamp}.csv")
    df_yahoo.to_csv(csv_yahoo, index=False, encoding="utf-8")
    logger.info(f"CSV de ExtractYahoo cru salvo em: {csv_yahoo}")
# Out:
# 15-10-25 21:02:21 [INFO] CSV de ExtractNews cru salvo em: ../data/raw\ExtractNews_15-10-25_21-02-21.csv
# INFO:PipelineLogger:CSV de ExtractNews cru salvo em: ../data/raw\ExtractNews_15-10-25_21-02-21.csv
# 15-10-25 21:02:21 [INFO] CSV de ExtractYahoo cru salvo em: ../data/raw\ExtractYahoo_15-10-25_21-02-21.csv
# INFO:PipelineLogger:CSV de ExtractYahoo cru salvo em: ../data/raw\ExtractYahoo_15-10-25_21-02-21.csv

# %%
transform = Transform()

df_news_clean = transform.clean_news(df_news)
df_yahoo_clean = transform.clean_yahoo(df_yahoo)

csv_news_clean = os.path.join(PROCESSED_DIR, f"ExtractNews_CLEAN_{timestamp}.csv")
df_news_clean.to_csv(csv_news_clean, index=False, encoding="utf-8")
logger.info(f"CSV de notícias tratado salvo em: {csv_news_clean}")

csv_yahoo_clean = os.path.join(PROCESSED_DIR, f"ExtractYahoo_CLEAN_{timestamp}.csv")
df_yahoo_clean.to_csv(csv_yahoo_clean, index=False, encoding="utf-8")
logger.info(f"CSV do Yahoo tratado salvo em: {csv_yahoo_clean}")

csv_news_removed = os.path.join(PROCESSED_DIR, f"ExtractNews_REMOVED_{timestamp}.csv")
transform.removed_news.to_csv(csv_news_removed, index=False, encoding="utf-8")
logger.info(f"CSV de notícias removidas salvo em: {csv_news_removed}")

csv_yahoo_removed = os.path.join(PROCESSED_DIR, f"ExtractYahoo_REMOVED_{timestamp}.csv")
transform.removed_yahoo.to_csv(csv_yahoo_removed, index=False, encoding="utf-8")
logger.info(f"CSV de Yahoo removidos salvo em: {csv_yahoo_removed}")
# Out:
# 15-10-25 21:02:21 [INFO] CSV de notícias tratado salvo em: ../data/processed\ExtractNews_CLEAN_15-10-25_21-02-21.csv
# INFO:PipelineLogger:CSV de notícias tratado salvo em: ../data/processed\ExtractNews_CLEAN_15-10-25_21-02-21.csv
# 15-10-25 21:02:21 [INFO] CSV do Yahoo tratado salvo em: ../data/processed\ExtractYahoo_CLEAN_15-10-25_21-02-21.csv
# INFO:PipelineLogger:CSV do Yahoo tratado salvo em: ../data/processed\ExtractYahoo_CLEAN_15-10-25_21-02-21.csv
# 15-10-25 21:02:21 [INFO] CSV de notícias removidas salvo em: ../data/processed\ExtractNews_REMOVED_15-10-25_21-02-21.csv
# INFO:PipelineLogger:CSV de notícias removidas salvo em: ../data/processed\ExtractNews_REMOVED_15-10-25_21-02-21.csv
# 15-10-25 21:02:21 [INFO] CSV de Yahoo removidos salvo em: ../data/processed\ExtractYahoo_REMOVED_15-10-25_21-02-21.csv
# INFO:PipelineLogger:CSV de Yahoo removidos salvo em: ../data/processed\ExtractYahoo_REMOVED_15-10-25_21-02-21.csv

# %%
loader = Load(DB_PATH)

inserted_news, ignored_news = loader.save_news(df_news_clean)
inserted_instr, ignored_instr = loader.save_instruments(df_yahoo_clean)
attempted_prices, _ = loader.save_prices(df_yahoo_clean)

logger.info("Carga dos dados concluída com sucesso no SQLite!")
# Out:
# 15-10-25 21:02:21 [INFO] Carga dos dados concluída com sucesso no SQLite!
# INFO:PipelineLogger:Carga dos dados concluída com sucesso no SQLite!

# %%
print("Pipeline finalizada!")
print(f"Total notícias cru: {len(df_news)}")
print(f"Total registros históricos cru: {len(df_yahoo)}")
print(f"Total notícias tratadas: {len(df_news_clean)}")
print(f"Total registros históricos tratados: {len(df_yahoo_clean)}")
print(f"Total notícias removidas: {len(transform.removed_news)}")
print(f"Total registros históricos removidos: {len(transform.removed_yahoo)}")

display(df_news.head(10))
display(df_news_clean.head(10))
display(transform.removed_news.head(10))

display(df_yahoo.head(10))
display(df_yahoo_clean.head(10))
display(transform.removed_yahoo.head(10))

logger.info(f"Log salvo em: {log_file}")
# Out:
# Pipeline finalizada!
# Total notícias cru: 161
# Total registros históricos cru: 1260
# Total notícias tratadas: 156
# Total registros históricos tratados: 1260
# Total notícias removidas: 5
# Total registros históricos removidos: 0
#    NoticiaID                                             titulo  \
# 0          1  Polícia prende Alex Gardenal, homem com extens...
# 1          2  Policiais receberam R$ 300 mil em propina para...
# 2          3  Motociclista morre atropelado por Hilux em For...
# 3          4           Assista às reportagens do CETV 1ª edição
# 4          5  Vídeo: polícia cumpre 12 mandados de prisão co...
# 5          6  Vídeo: homem morre durante exercício físico em...
# 6          7  Assaltante derruba motociclista em movimento e...
# 7          8  Governo passa a indicar faixa etária para apps...
# 8          9  Lula confirma reunião e brinca sobre Trump: 'P...
# 9         10  O que define um 'serial killer'? Especialistas...
#
#                                                  url  \
# 0  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 1  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 2  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 3  https://g1.globo.com/ce/ceara/edicao/2025/05/2...
# 4  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 5  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 6  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 7  https://g1.globo.com/politica/noticia/2025/10/...
# 8  https://g1.globo.com/politica/noticia/2025/10/...
# 9  https://g1.globo.com/ciencia/noticia/2025/10/1...
#
#                                                 lead  \
# 0  Alex Gardenal foi preso novamente na última te...
# 1  Uma investigação do Ministério Público do Esta...
# 2  Um acidente de trânsito resultou na morte de u...
# 3
# 4  A Polícia Civil do Ceará cumpriu, na madrugada...
# 5  Um homem de 44 anos faleceu na noite da última...
# 6  Um motociclista foi vítima de um assalto na ta...
# 7  O ministro da Justiça e Segurança Pública, Ric...
# 8  Presidente Lula confirmou nesta quarta-feira (...
# 9  Caso da estudante de Direito apontada pela pol...
#
#                         dataHora
# 0  2025-10-15T16:35:19.903-03:00
# 1  2025-10-15T13:39:51.220-03:00
# 2  2025-10-15T12:51:37.557-03:00
# 3
# 4  2025-10-15T11:17:10.510-03:00
# 5  2025-10-14T11:26:58.739-03:00
# 6  2025-10-15T10:56:52.579-03:00
# 7  2025-10-15T15:35:05.673-03:00
# 8  2025-10-15T12:13:56.886-03:00
# 9  2025-10-15T12:14:26.315-03:00
#    NoticiaID                                             titulo  \
# 0          1  Polícia prende Alex Gardenal, homem com extens...
# 1          2  Policiais receberam R$ 300 mil em propina para...
# 2          3  Motociclista morre atropelado por Hilux em For...
# 3          4           Assista às reportagens do CETV 1ª edição
# 4          5  Vídeo: polícia cumpre 12 mandados de prisão co...
# 5          6  Vídeo: homem morre durante exercício físico em...
# 6          7  Assaltante derruba motociclista em movimento e...
# 7          8  Governo passa a indicar faixa etária para apps...
# 8          9  Lula confirma reunião e brinca sobre Trump: 'P...
# 9         10  O que define um 'serial killer'? Especialistas...
#
#                                                  url  \
# 0  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 1  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 2  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 3  https://g1.globo.com/ce/ceara/edicao/2025/05/2...
# 4  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 5  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 6  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 7  https://g1.globo.com/politica/noticia/2025/10/...
# 8  https://g1.globo.com/politica/noticia/2025/10/...
# 9  https://g1.globo.com/ciencia/noticia/2025/10/1...
#
#                                                 lead           dataHora
# 0  Alex Gardenal foi preso novamente na última te...  15/10/25 16:35:19
# 1  Uma investigação do Ministério Público do Esta...  15/10/25 13:39:51
# 2  Um acidente de trânsito resultou na morte de u...  15/10/25 12:51:37
# 3                                          Sem dados          Sem dados
# 4  A Polícia Civil do Ceará cumpriu, na madrugada...  15/10/25 11:17:10
# 5  Um homem de 44 anos faleceu na noite da última...  14/10/25 11:26:58
# 6  Um motociclista foi vítima de um assalto na ta...  15/10/25 10:56:52
# 7  O ministro da Justiça e Segurança Pública, Ric...  15/10/25 15:35:05
# 8  Presidente Lula confirmou nesta quarta-feira (...  15/10/25 12:13:56
# 9  Caso da estudante de Direito apontada pela pol...  15/10/25 12:14:26
#    NoticiaID                                             titulo  \
# 0         25  PGR pede que STF reabra inquérito sobre supost...
# 1         26  Correios: queda nas receitas, gastos com pesso...
# 2         31  Governo passa a classificar aplicativos e cria...
# 3         40  Lula confirma reunião de negociação com EUA ne...
# 4         45  O que define um 'serial killer'? Veja o que di...
#
#                                                  url  \
# 0  https://g1.globo.com/politica/noticia/2025/10/...
# 1  https://g1.globo.com/economia/noticia/2025/10/...
# 2  https://g1.globo.com/politica/noticia/2025/10/...
# 3  https://g1.globo.com/politica/noticia/2025/10/...
# 4  https://g1.globo.com/ciencia/noticia/2025/10/1...
#
#                                                 lead  \
# 0  A PGR pediu nesta quarta-feira (15) que o STF ...
# 1  Correios anunciaram que buscam R$ 20 bilhões e...
# 2  O ministro da Justiça e Segurança Pública, Ric...
# 3  Presidente Lula confirmou nesta quarta-feira (...
# 4  Caso da estudante de Direito apontada pela pol...
#
#                         dataHora                          url_hash
# 0  2025-10-15T18:24:42.845-03:00  d964e0cbdf26877aff02d3075a8318d4
# 1  2025-10-15T17:10:15.636-03:00  959fa6dcf87a2647189d9ee21f5e0f33
# 2  2025-10-15T15:35:05.673-03:00  534fb2956b473f51999e5af955b64f83
# 3  2025-10-15T12:13:56.886-03:00  59983ededc2697ac4716f4dcdad5e113
# 4  2025-10-15T12:14:26.315-03:00  4e3b4b9c34a6069de7e051a4b9ed852d
#          Date        Open        High         Low       Close     Volume  \
# 0  2025-04-16  104.536850  106.776566  100.437360  104.476852  397016900
# 1  2025-04-17  104.436853  104.456855  100.037413  101.477226  292517500
# 2  2025-04-21   98.757571   99.427492   95.028044   96.897812  288501100
# 3  2025-04-22   98.767569   99.797438   97.267758   98.877556  241004800
# 4  2025-04-23  104.506845  104.786816  102.007159  102.697075  247526000
# 5  2025-04-24  103.466977  106.526590  103.097021  106.416603  220815000
# 6  2025-04-25  106.836560  111.905922  105.716706  110.996040  251064700
# 7  2025-04-28  109.676194  110.356109  106.006651  108.716316  207708500
# 8  2025-04-29  107.656450  110.186131  107.426484  109.006279  170444300
# 9  2025-04-30  104.456859  108.906296  104.066908  108.906296  235044600
#
#    Dividends  Stock Splits ticker             Empresa       Setor  \
# 0        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 1        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 2        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 3        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 4        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 5        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 6        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 7        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 8        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 9        0.0           0.0   NVDA  NVIDIA Corporation  Technology
#
#         Industria Moeda           Pais Bolsa      Data_Coletada
# 0  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 1  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 2  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 3  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 4  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 5  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 6  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 7  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 8  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
# 9  Semiconductors   USD  United States   NMS  15/10/25 21:02:07
#        Date        Open        High         Low       Close     Volume  \
# 0  16/04/25  104.536850  106.776566  100.437360  104.476852  397016900
# 1  17/04/25  104.436853  104.456855  100.037413  101.477226  292517500
# 2  21/04/25   98.757571   99.427492   95.028044   96.897812  288501100
# 3  22/04/25   98.767569   99.797438   97.267758   98.877556  241004800
# 4  23/04/25  104.506845  104.786816  102.007159  102.697075  247526000
# 5  24/04/25  103.466977  106.526590  103.097021  106.416603  220815000
# 6  25/04/25  106.836560  111.905922  105.716706  110.996040  251064700
# 7  28/04/25  109.676194  110.356109  106.006651  108.716316  207708500
# 8  29/04/25  107.656450  110.186131  107.426484  109.006279  170444300
# 9  30/04/25  104.456859  108.906296  104.066908  108.906296  235044600
#
#    Dividends  Stock Splits ticker             Empresa       Setor  \
# 0        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 1        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 2        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 3        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 4        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 5        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 6        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 7        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 8        0.0           0.0   NVDA  NVIDIA Corporation  Technology
# 9        0.0           0.0   NVDA  NVIDIA Corporation  Technology
#
#         Industria Moeda           Pais Bolsa Data_Coletada
# 0  Semiconductors   USD  United States   NMS      15/10/25
# 1  Semiconductors   USD  United States   NMS      15/10/25
# 2  Semiconductors   USD  United States   NMS      15/10/25
# 3  Semiconductors   USD  United States   NMS      15/10/25
# 4  Semiconductors   USD  United States   NMS      15/10/25
# 5  Semiconductors   USD  United States   NMS      15/10/25
# 6  Semiconductors   USD  United States   NMS      15/10/25
# 7  Semiconductors   USD  United States   NMS      15/10/25
# 8  Semiconductors   USD  United States   NMS      15/10/25
# 9  Semiconductors   USD  United States   NMS      15/10/25
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Dividends, Stock Splits, ticker, Empresa, Setor, Industria, Moeda, Pais, Bolsa, Data_Coletada, hash]
# Index: []
# 15-10-25 21:02:21 [INFO] Log salvo em: ../logs/pipeline\PipelineLogger_15-10-25_20-59-43.log
# INFO:PipelineLogger:Log salvo em: ../logs/pipeline\PipelineLogger_15-10-25_20-59-43.log

# %%
import sqlite3
import pandas as pd



conn = sqlite3.connect(DB_PATH)

tables = ["news", "instruments", "prices"]

for table in tables:
    print(f"===== {table.upper()} =====")
    try:
        df = pd.read_sql_query(f"SELECT * FROM {table} LIMIT 10", conn)
        display(df)
        print(
            f"Total registros na tabela {table}: {pd.read_sql_query(f'SELECT COUNT(*) as count FROM {table}', conn)['count'][0]}\n"
        )
    except Exception as e:
        print(f"Erro ao ler tabela {table}: {e}\n")

conn.close()
# Out:
# ===== NEWS =====
#    id  noticia_id                                             titulo  \
# 0   1           1  Vídeo: polícia cumpre 12 mandados de prisão co...
# 1   2           2  Vídeo: homem morre durante exercício físico em...
# 2   3           3  Assaltante derruba motociclista em movimento e...
# 3   4           4           Assista às reportagens do CETV 1ª edição
# 4   5           5  Vagões do metrô ficam superlotados com a reduç...
# 5   6           6  Vídeo: motociclista atropela corredor e foge s...
# 6   7           7  Calçada em Fortaleza vira 'atalho' para motoci...
# 7   8           8  Trump autoriza ação secreta da CIA e 'operaçõe...
# 8   9           9  Lula confirma reunião e brinca sobre Trump: 'P...
# 9  10          10  Sem dinheiro nem para demitir, Correios buscam...
#
#                                                  url  \
# 0  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 1  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 2  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 3  https://g1.globo.com/ce/ceara/edicao/2025/05/2...
# 4  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 5  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 6  https://g1.globo.com/ce/ceara/noticia/2025/10/...
# 7  https://g1.globo.com/mundo/noticia/2025/10/15/...
# 8  https://g1.globo.com/politica/noticia/2025/10/...
# 9  https://g1.globo.com/economia/noticia/2025/10/...
#
#                                                 lead          data_hora
# 0  A Polícia Civil do Ceará cumpriu, na madrugada...  15/10/25 11:17:10
# 1  Um homem de 44 anos faleceu na noite da última...  14/10/25 11:26:58
# 2  Um motociclista foi vítima de um assalto na ta...  15/10/25 10:56:52
# 3                                          Sem dados          Sem dados
# 4  Falhas técnicas em duas composições que operam...  15/10/25 07:22:31
# 5  Um homem foi atropelado enquanto corria com a ...  15/10/25 05:03:06
# 6  Uma calçada no cruzamento da Rua 15 de Novembr...  15/10/25 08:31:12
# 7  O governo de Donald Trump autorizou ações secr...  15/10/25 15:43:10
# 8  Presidente Lula confirmou nesta quarta-feira (...  15/10/25 12:13:56
# 9  Os Correios anunciaram nesta quarta-feira (15)...  15/10/25 12:51:40
# Total registros na tabela news: 255
#
# ===== INSTRUMENTS =====
#    instrument_id                       ticker                         nome  \
# 0              1           NVIDIA Corporation           NVIDIA Corporation
# 1              2        Microsoft Corporation        Microsoft Corporation
# 2              3                   Apple Inc.                   Apple Inc.
# 3              4             Amazon.com, Inc.             Amazon.com, Inc.
# 4              5                  Tesla, Inc.                  Tesla, Inc.
# 5              6                Broadcom Inc.                Broadcom Inc.
# 6              7         Meta Platforms, Inc.         Meta Platforms, Inc.
# 7              8  Berkshire Hathaway Inc. New  Berkshire Hathaway Inc. New
# 8              9        JP Morgan Chase & Co.        JP Morgan Chase & Co.
# 9             10        Eli Lilly and Company        Eli Lilly and Company
#
#                     setor           pais bolsa
# 0              Technology  United States   NMS
# 1              Technology  United States   NMS
# 2              Technology  United States   NMS
# 3       Consumer Cyclical  United States   NMS
# 4       Consumer Cyclical  United States   NMS
# 5              Technology  United States   NMS
# 6  Communication Services  United States   NMS
# 7      Financial Services  United States   NYQ
# 8      Financial Services  United States   NYQ
# 9              Healthcare  United States   NYQ
# Total registros na tabela instruments: 20
#
# ===== PRICES =====
#          date              ticker        open        high         low  \
# 0  2025-04-15  NVIDIA Corporation  110.956042  113.605710  110.486099
# 1  2025-04-16  NVIDIA Corporation  104.536850  106.776566  100.437360
# 2  2025-04-17  NVIDIA Corporation  104.436853  104.456855  100.037413
# 3  2025-04-21  NVIDIA Corporation   98.757571   99.427492   95.028044
# 4  2025-04-22  NVIDIA Corporation   98.767569   99.797438   97.267758
# 5  2025-04-23  NVIDIA Corporation  104.506845  104.786816  102.007159
# 6  2025-04-24  NVIDIA Corporation  103.466977  106.526590  103.097021
# 7  2025-04-25  NVIDIA Corporation  106.836560  111.905922  105.716706
# 8  2025-04-28  NVIDIA Corporation  109.676194  110.356109  106.006651
# 9  2025-04-29  NVIDIA Corporation  107.656450  110.186131  107.426484
#
#         close     volume data_coletada
# 0  112.185883  228966900      15/10/25
# 1  104.476852  397016900      15/10/25
# 2  101.477226  292517500      15/10/25
# 3   96.897812  288501100      15/10/25
# 4   98.877556  241004800      15/10/25
# 5  102.697075  247526000      15/10/25
# 6  106.416603  220815000      15/10/25
# 7  110.996040  251064700      15/10/25
# 8  108.716316  207708500      15/10/25
# 9  109.006279  170444300      15/10/25
# Total registros na tabela prices: 2540
